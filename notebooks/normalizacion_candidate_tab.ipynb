# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#    candidate_id  Age Accessibility        EdLevel  Employment Gender  \
# 0             0  <35            No         Master           1    Man
# 1             1  <35            No  Undergraduate           1    Man
# 2             2  <35            No         Master           1    Man
# 3             3  <35            No  Undergraduate           1    Man
# 4             4  >35            No            PhD           0    Man
#
#   MentalHealth MainBranch  YearsCode  YearsCodePro    Country  PreviousSalary  \
# 0           No        Dev          7             4     Sweden         51552.0
# 1           No        Dev         12             5      Spain         46482.0
# 2           No        Dev         15             6    Germany         77290.0
# 3           No        Dev          9             6     Canada         46135.0
# 4           No     NotDev         40            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  Employed
# ...

# %%
df_candidate = df[['candidate_id', 'Age', 'Gender', 'Country']]
df_candidate.head(5)
# Out:
#    candidate_id  Age Gender    Country
# 0             0  <35    Man     Sweden
# 1             1  <35    Man      Spain
# 2             2  <35    Man    Germany
# 3             3  <35    Man     Canada
# 4             4  >35    Man  Singapore

# %%
df_candidate.to_csv('../data/split_tabs/candidate.csv',index=False)
df_candidate.head()
# Out:
#    candidate_id  Age Gender    Country
# 0             0  <35    Man     Sweden
# 1             1  <35    Man      Spain
# 2             2  <35    Man    Germany
# 3             3  <35    Man     Canada
# 4             4  >35    Man  Singapore
