# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#               candidate_id  Age Accessibility        EdLevel  Employment  \
# education_id
# 0                        0  <35            No         Master           1
# 1                        1  <35            No  Undergraduate           1
# 2                        2  <35            No         Master           1
# 3                        3  <35            No  Undergraduate           1
# 4                        4  >35            No            PhD           0
#
#              Gender MentalHealth MainBranch  YearsCode  YearsCodePro  \
# education_id
# 0               Man           No        Dev          7             4
# 1               Man           No        Dev         12             5
# 2               Man           No        Dev         15             6
# 3               Man           No        Dev          9             6
# 4               Man           No     NotDev         40            30
#
#                 Country  PreviousSalary  \
# education_id
# ...

# %%
df.index.name = 'education_id'

# %%
df_educational_information = df[['EdLevel','candidate_id']]
df_educational_information.head(5)
# Out:
#                     EdLevel  candidate_id
# education_id
# 0                    Master             0
# 1             Undergraduate             1
# 2                    Master             2
# 3             Undergraduate             3
# 4                       PhD             4

# %%
df_educational_information.to_csv('../data/split_tabs/educational_information.csv')
df_educational_information.head()
# Out:
#                     EdLevel  candidate_id
# education_id
# 0                    Master             0
# 1             Undergraduate             1
# 2                    Master             2
# 3             Undergraduate             3
# 4                       PhD             4
