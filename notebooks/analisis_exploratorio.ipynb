# %% [markdown]
# # Analisis exploratorio - Proyecto 1= DB Postulantes

# %%
# %pip install seaborn matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 84.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 65.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 106.7 MB/s eta 0:00:00
# ...
#
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración inicial
# %matplotlib inline

# Configuración de seaborn
sns.set_theme(style="whitegrid", palette="deep")
sns.set_context("notebook", font_scale=1.1)

# Configuración de matplotlib
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300
# %config InlineBackend.figure_format = 'retina'

# Paletas de colores personalizadas
colors = sns.color_palette("husl", 8)
sns.set_palette(colors)
##pd.set_option("display.max_rows", None)##

# %%
df = pd.read_csv('../data/raw/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 0           0  <35            No         Master           1    Man
# 1           1  <35            No  Undergraduate           1    Man
# 2           2  <35            No         Master           1    Man
# 3           3  <35            No  Undergraduate           1    Man
# 4           4  >35            No            PhD           0    Man
#
#   MentalHealth MainBranch  YearsCode  YearsCodePro    Country  PreviousSalary  \
# 0           No        Dev          7             4     Sweden         51552.0
# 1           No        Dev         12             5      Spain         46482.0
# 2           No        Dev         15             6    Germany         77290.0
# 3           No        Dev          9             6     Canada         46135.0
# 4           No     NotDev         40            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  Employed
# ...

# %%
df.tail(5)
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment     Gender  \
# 73457       73457  <35            No  Undergraduate           1        Man
# 73458       73458  >35            No  Undergraduate           1        Man
# 73459       73459  <35            No  Undergraduate           1        Man
# 73460       73460  <35           Yes  Undergraduate           1        Man
# 73461       73461  <35            No         Master           1  NonBinary
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 73457           No        Dev          7             2
# 73458           No        Dev         21            16
# 73459           No        Dev          4             3
# 73460          Yes        Dev          5             1
# 73461           No        Dev         10             3
#
#                                                  Country  PreviousSalary  \
# 73457                                            Germany         41058.0
# ...

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73462 entries, 0 to 73461
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      73462 non-null  int64
#  1   Age             73462 non-null  object
#  2   Accessibility   73462 non-null  object
#  3   EdLevel         73462 non-null  object
#  4   Employment      73462 non-null  int64
#  5   Gender          73462 non-null  object
#  6   MentalHealth    73462 non-null  object
#  7   MainBranch      73462 non-null  object
#  8   YearsCode       73462 non-null  int64
#  9   YearsCodePro    73462 non-null  int64
#  10  Country         73462 non-null  object
#  11  PreviousSalary  73462 non-null  float64
#  12  HaveWorkedWith  73399 non-null  object
#  13  ComputerSkills  73462 non-null  int64
#  14  Employed        73462 non-null  int64
# dtypes: float64(1), int64(6), object(8)
# memory usage: 8.4+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    Employment     YearsCode  YearsCodePro  PreviousSalary  \
# count  73462.000000  73462.000000  73462.000000  73462.000000    73462.000000
# mean   36730.500000      0.883096     14.218902      9.098377    67750.260611
# std    21206.797075      0.321308      9.405172      7.960201    49488.142118
# min        0.000000      0.000000      0.000000      0.000000        1.000000
# 25%    18365.250000      1.000000      7.000000      3.000000    28839.000000
# 50%    36730.500000      1.000000     12.000000      7.000000    57588.000000
# 75%    55095.750000      1.000000     20.000000     12.000000    95979.000000
# max    73461.000000      1.000000     50.000000     50.000000   224000.000000
#
#        ComputerSkills      Employed
# count    73462.000000  73462.000000
# mean        13.428221      0.536223
# std          7.057835      0.498690
# min          0.000000      0.000000
# 25%          8.000000      0.000000
# 50%         13.000000      1.000000
# ...

# %% [markdown]
# # A;os promedio de experiencia profesional de los candidatos

# %%
MeanYearsPro = df['YearsCodePro'].mean()

print(f'El promedio de a;os de experiencia profesional de los candidatos es {int(MeanYearsPro)}')
# Out:
# El promedio de a;os de experiencia profesional de los candidatos es 9

# %%
MeanYears = df['YearsCode'].mean()

print(f'El promedio de a;os de experiencia de los candidatos es {int(MeanYears)}')
# Out:
# El promedio de a;os de experiencia de los candidatos es 14

# %% [markdown]
# # Sueldo mas alto segun cada pais

# %%
TopSalaryXCountry = df.groupby('Country')['PreviousSalary'].max()

print(TopSalaryXCountry.sort_values())
# Out:
# Country
# Burundi                                                   1584.0
# Seychelles                                                2436.0
# Saint Lucia                                               9768.0
# Togo                                                      9888.0
# Saint Kitts and Nevis                                    10380.0
# Gambia                                                   11796.0
# Somalia                                                  12000.0
# Suriname                                                 13188.0
# Lesotho                                                  14436.0
# Dominica                                                 18501.0
# Tajikistan                                               18564.0
# Mauritania                                               19248.0
# Mozambique                                               22572.0
# Fiji                                                     23144.0
# ...

# %%
df['Country'].unique()
# Out:
# array(['Sweden', 'Spain', 'Germany', 'Canada', 'Singapore', 'France',
#        'Switzerland',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'Russian Federation', 'Israel', 'Turkey',
#        'United States of America', 'Brazil', 'Bulgaria', 'Greece',
#        'Italy', 'Netherlands', 'Poland', 'Hungary', 'Pakistan', 'Nigeria',
#        'Albania', 'Bangladesh', 'Viet Nam', 'Romania', 'Sri Lanka',
#        'India', 'Lithuania', 'Ukraine', 'Croatia', 'Georgia', 'Denmark',
#        'Ireland', 'Lebanon', 'Bahrain', 'Egypt', 'Colombia', 'Australia',
#        'Chile', 'Indonesia', 'Iran, Islamic Republic of...', 'Portugal',
#        'Slovakia', 'Armenia', 'Finland', 'Hong Kong (S.A.R.)',
#        'Argentina', 'Costa Rica', 'Peru', 'Japan', 'Belgium',
#        'United Arab Emirates', 'Bolivia', 'Austria', 'South Africa',
#        'Norway', 'Serbia', 'Malta', 'Malaysia', 'Czech Republic',
#        'Belarus', 'Madagascar', 'Kenya', 'Slovenia', 'Uruguay',
# ...

# %%
#df['Country'].value_counts()
display(df['Country'].value_counts())
# Out:
# Country
# United States of America                                14696
# Germany                                                  5395
# India                                                    5360
# United Kingdom of Great Britain and Northern Ireland     4688
# Canada                                                   2779
# France                                                   2650
# Brazil                                                   2624
# Poland                                                   1922
# Netherlands                                              1761
# Spain                                                    1712
# Australia                                                1567
# Italy                                                    1470
# Sweden                                                   1366
# Russian Federation                                       1327
# Switzerland                                               922
# ...

# %%
df[df['Country']=='Liberia']
# Out:
#        Unnamed: 0  Age Accessibility     EdLevel  Employment Gender  \
# 16590       16590  <35            No  NoHigherEd           0    Man
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  Country  \
# 16590           No        Dev          5             5  Liberia
#
#        PreviousSalary                                     HaveWorkedWith  \
# 16590            12.0  JavaScript;Python;Ruby;SQL;TypeScript;VBA;Angu...
#
#        ComputerSkills  Employed
# 16590              21         1

# %%
df = df.drop(df[df['Country']=='Liberia'].index)

# %% [markdown]
# # Candidatos con mas de 10 a;os de experiencia X pais

# %%
df_tenyearscode = df[df['YearsCode']>=10]

df_tenyearscode.head(5)
# Out:
#    Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 1           1  <35            No  Undergraduate           1    Man
# 2           2  <35            No         Master           1    Man
# 4           4  >35            No            PhD           0    Man
# 6           6  >35            No         Master           1    Man
# 7           7  <35            No         Master           1    Man
#
#   MentalHealth MainBranch  YearsCode  YearsCodePro      Country  \
# 1           No        Dev         12             5        Spain
# 2           No        Dev         15             6      Germany
# 4           No     NotDev         40            30    Singapore
# 6           No        Dev         26            18      Germany
# 7           No     NotDev         14             5  Switzerland
#
#    PreviousSalary                                     HaveWorkedWith  \
# 1         46482.0  Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# ...

# %%
display(df_tenyearscode['Country'].value_counts())
# Out:
# Country
# United States of America                                10106
# Germany                                                  3951
# United Kingdom of Great Britain and Northern Ireland     3370
# India                                                    2174
# Canada                                                   1925
# France                                                   1727
# Brazil                                                   1524
# Netherlands                                              1262
# Australia                                                1217
# Spain                                                    1113
# Poland                                                   1105
# Italy                                                    1077
# Sweden                                                   1027
# Russian Federation                                        838
# Switzerland                                               698
# ...

# %%
YearsCodeXCountry = df_tenyearscode.groupby('Country')['YearsCode'].max()

print(YearsCodeXCountry.sort_values())
# Out:
# Country
# Togo                                                    10
# Malawi                                                  11
# Suriname                                                11
# Lesotho                                                 12
# Monaco                                                  12
# Tajikistan                                              12
# Fiji                                                    13
# Guyana                                                  13
# Sudan                                                   14
# Algeria                                                 14
# Seychelles                                              15
# Belize                                                  15
# Niger                                                   15
# Democratic Republic of the Congo                        15
# Bhutan                                                  15
# Congo, Republic of the...                               16
# ...

# %%
df_tenyearscode[(df_tenyearscode['Country']=='United States of America')&(df_tenyearscode['Age']=='>35')].shape
# Out:
# (6078, 15)

# %% [markdown]
# # Sueldo promedio X Pais

# %%
MeanSalaryXCountry = df.groupby('Country')['PreviousSalary'].mean()

print(MeanSalaryXCountry.sort_values())
# Out:
# Country
# Burundi                                                   1584.000000
# Seychelles                                                2436.000000
# Togo                                                      4759.200000
# Cameroon                                                  7013.869565
# Lesotho                                                   7620.000000
# Tajikistan                                                7671.428571
# Myanmar                                                   8401.655172
# Mozambique                                                8771.000000
# Suriname                                                  8804.000000
# Madagascar                                                8990.555556
# Sudan                                                     8993.400000
# Saint Lucia                                               9324.000000
# Benin                                                    10238.666667
# ...

# %% [markdown]
# # Skills X Country (Min, Max & Mean)

# %%
MinSkillsXCountry = df.groupby('Country')['ComputerSkills'].min()

print(MinSkillsXCountry.sort_values())
# Out:
# Country
# Albania                                                  0
# Argentina                                                0
# Australia                                                0
# Bangladesh                                               0
# Belarus                                                  0
# Colombia                                                 0
# Brazil                                                   0
# Bulgaria                                                 0
# Canada                                                   0
# Chile                                                    0
# China                                                    0
# Egypt                                                    0
# France                                                   0
# Germany                                                  0
# Israel                                                   0
# India                                                    0
# ...

# %%
MaxSkillsXCountry = df.groupby('Country')['ComputerSkills'].max()

print(MaxSkillsXCountry.sort_values())
# Out:
# Country
# Saint Kitts and Nevis                                     6
# Seychelles                                                6
# Saint Vincent and the Grenadines                          7
# Djibouti                                                  9
# Gambia                                                   13
# Guyana                                                   15
# Monaco                                                   15
# Belize                                                   15
# Suriname                                                 15
# Saint Lucia                                              15
# Dominica                                                 17
# Timor-Leste                                              17
# Mali                                                     19
# Isle of Man                                              20
# Burkina Faso                                             21
# ...

# %%
MeanSkillsXCountry = df.groupby('Country')['ComputerSkills'].mean()

print(MeanSkillsXCountry.sort_values())
# Out:
# Country
# Saint Kitts and Nevis                                    6.000000
# Seychelles                                               6.000000
# Saint Vincent and the Grenadines                         7.000000
# Belize                                                   9.000000
# Djibouti                                                 9.000000
# Saint Lucia                                              9.000000
# Kyrgyzstan                                              10.555556
# Guyana                                                  10.833333
# Uzbekistan                                              11.155556
# Nomadic                                                 11.400000
# Turkmenistan                                            11.777778
# Cyprus                                                  11.826923
# Russian Federation                                      11.847023
# Yemen                                                   11.888889
# ...

# %%
df_MinSkillsXUSA = df[(df['Country']=='United States of America')&(df['ComputerSkills']==0)]

df_MinSkillsXUSA.head()
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 2443         2443  >35            No          Other           1    Man
# 11074       11074  <35            No         Master           1    Man
# 11498       11498  <35            No  Undergraduate           1  Woman
# 15390       15390  >35            No          Other           1    Man
# 18126       18126  >35            No          Other           1    Man
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 2443            No        Dev          7             6
# 11074           No        Dev          6             4
# 11498           No        Dev         12             8
# 15390           No        Dev         35            30
# 18126          Yes     NotDev         33            18
#
#                         Country  PreviousSalary HaveWorkedWith  \
# 2443   United States of America         85000.0            NaN
# 11074  United States of America         82000.0            NaN
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Age                0
# Accessibility      0
# EdLevel            0
# Employment         0
# Gender             0
# MentalHealth       0
# MainBranch         0
# YearsCode          0
# YearsCodePro       0
# Country            0
# PreviousSalary     0
# HaveWorkedWith    63
# ComputerSkills     0
# Employed           0
# dtype: int64

# %%
df_JuniorXYearsCodePro = df[df['YearsCodePro']<=3]

df_JuniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0    Employment     YearsCode  YearsCodePro  PreviousSalary  \
# count  19408.000000  19408.000000  19408.000000  19408.000000    19408.000000
# mean   35925.946311      0.897877      6.331719      1.855575    40504.125206
# std    20994.974496      0.302818      3.487099      1.057870    37388.133345
# min        5.000000      0.000000      0.000000      0.000000        1.000000
# 25%    17929.000000      1.000000      4.000000      1.000000    11832.000000
# 50%    36244.500000      1.000000      6.000000      2.000000    30253.000000
# 75%    53538.500000      1.000000      8.000000      3.000000    57093.000000
# max    73461.000000      1.000000     43.000000      3.000000   220000.000000
#
#        ComputerSkills      Employed
# count    19408.000000  19408.000000
# mean        12.819817      0.512624
# std          6.733305      0.499853
# min          0.000000      0.000000
# 25%          8.000000      0.000000
# 50%         12.000000      1.000000
# ...

# %%
df_SSeniorXYearsCodePro = df[(df['YearsCodePro']>=4) & (df['YearsCodePro']<=8)]

df_SSeniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0    Employment     YearsCode  YearsCodePro  PreviousSalary  \
# count  24672.000000  24672.000000  24672.000000  24672.000000    24672.000000
# mean   36536.017875      0.906128     10.461454      5.736219    63584.660101
# std    21258.366275      0.291656      4.141470      1.381466    45034.329945
# min        0.000000      0.000000      0.000000      4.000000        1.000000
# 25%    17960.750000      1.000000      8.000000      5.000000    29832.000000
# 50%    36692.000000      1.000000     10.000000      6.000000    53748.000000
# 75%    54985.250000      1.000000     12.000000      7.000000    86478.000000
# max    73456.000000      1.000000     50.000000      8.000000   223615.000000
#
#        ComputerSkills      Employed
# count    24672.000000  24672.000000
# mean        13.774887      0.541667
# std          7.058244      0.498271
# min          0.000000      0.000000
# 25%          9.000000      0.000000
# 50%         13.000000      1.000000
# ...

# %%
df_SeniorXYearsCodePro = df[df['YearsCodePro']>=9]

df_SeniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0    Employment     YearsCode  YearsCodePro  PreviousSalary  \
# count  29381.000000  29381.000000  29381.000000  29381.000000    29381.000000
# mean   37425.955618      0.854021     22.584425     16.706137    89248.318199
# std    21281.054433      0.353091      8.706585      7.353069    50298.247344
# min        4.000000      0.000000      0.000000      9.000000        1.000000
# 25%    19009.000000      1.000000     16.000000     11.000000    51589.000000
# 50%    37368.000000      1.000000     20.000000     15.000000    80000.000000
# 75%    56371.000000      1.000000     28.000000     20.000000   122796.000000
# max    73458.000000      1.000000     50.000000     50.000000   224000.000000
#
#        ComputerSkills      Employed
# count    29381.000000  29381.000000
# mean        13.538750      0.547224
# std          7.239478      0.497773
# min          0.000000      0.000000
# 25%          8.000000      0.000000
# 50%         13.000000      1.000000
# ...

# %% [markdown]
# # Junior, SSenior & Senior X YearsCodePro X Gender

# %%
GenderJunior = df_JuniorXYearsCodePro.groupby('Gender')

print(GenderJunior.size())
# Out:
# Gender
# Man          17749
# NonBinary      362
# Woman         1297
# dtype: int64

# %%
GenderSSenior = df_SSeniorXYearsCodePro.groupby('Gender')

print(GenderSSenior.size())
# Out:
# Gender
# Man          22839
# NonBinary      488
# Woman         1345
# dtype: int64

# %%
GenderSenior = df_SeniorXYearsCodePro.groupby('Gender')

print(GenderSenior.size())
# Out:
# Gender
# Man          27984
# NonBinary      521
# Woman          876
# dtype: int64

# %% [markdown]
# # Graficos

# %% [markdown]
# # Edad - Seaborn

# %%
sns.countplot(data=df, x='Age')
plt.title('Distribucion por grupo etario')
# Out:
# Text(0.5, 1.0, 'Distribucion por grupo etario')

# %% [markdown]
# # Salario previo

# %%
sns.boxplot(data=df, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary'>

# %% [markdown]
# # Edad X Salario previo

# %%
sns.boxplot(data=df, x='Age', y='PreviousSalary')
# Out:
# <Axes: xlabel='Age', ylabel='PreviousSalary'>

# %% [markdown]
# # Genero X Salario previo

# %%
sns.boxplot(data=df, x='Gender', y='PreviousSalary')
# Out:
# <Axes: xlabel='Gender', ylabel='PreviousSalary'>

# %% [markdown]
# # Salario X Nivel educativo

# %%
sns.boxplot(data=df, x='EdLevel', y='PreviousSalary')
# Out:
# <Axes: xlabel='EdLevel', ylabel='PreviousSalary'>

# %% [markdown]
# # Distribucion de salarios - Histograma

# %%
sns.histplot(data=df, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %% [markdown]
# # Distribucion de salarios - Seniority

# %%
#Senior
sns.histplot(data=df_SeniorXYearsCodePro, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %%
#SSenior
sns.histplot(data=df_SSeniorXYearsCodePro, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %%
#Junior
sns.histplot(data=df_JuniorXYearsCodePro, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %% [markdown]
# # USA - Distribucion de salarios X Seniority

# %%
df_USA = df[df['Country']=='United States of America']

df_USA.head()
# Out:
#     Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 13          13  <35            No  Undergraduate           1    Man
# 25          25  >35            No  Undergraduate           1    Man
# 32          32  <35            No            PhD           1    Man
# 48          48  <35            No  Undergraduate           1    Man
# 52          52  <35            No  Undergraduate           1    Man
#
#    MentalHealth MainBranch  YearsCode  YearsCodePro                   Country  \
# 13           No        Dev          8             0  United States of America
# 25           No        Dev         25            15  United States of America
# 32           No        Dev         18             1  United States of America
# 48           No        Dev         12             6  United States of America
# 52           No        Dev          7             1  United States of America
#
#     PreviousSalary                                     HaveWorkedWith  \
# ...

# %%
#Senior
df_USASeniorXYearsCodePro = df_USA[df_USA['YearsCodePro']>=9]

df_USASeniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0   Employment    YearsCode  YearsCodePro  PreviousSalary  \
# count   7022.000000  7022.000000  7022.000000   7022.000000     7022.000000
# mean   38229.983623     0.936770    24.605241     18.599259   139918.344346
# std    21337.903569     0.243393     9.659343      8.614505    41757.406414
# min       25.000000     0.000000     1.000000      9.000000        1.000000
# 25%    21183.750000     1.000000    17.000000     11.000000   110000.000000
# 50%    38097.000000     1.000000    23.000000     16.000000   140000.000000
# 75%    58292.750000     1.000000    30.000000     24.000000   170000.000000
# max    73458.000000     1.000000    50.000000     50.000000   224000.000000
#
#        ComputerSkills     Employed
# count     7022.000000  7022.000000
# mean        13.628169     0.573483
# std          7.097206     0.494606
# min          0.000000     0.000000
# 25%          9.000000     0.000000
# 50%         13.000000     1.000000
# ...

# %%
#SENIOR USA
sns.histplot(data=df_USASeniorXYearsCodePro, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %%
df_USASSeniorXYearsCodePro = df_USA[(df_USA['YearsCodePro']>=4) & (df_USA['YearsCodePro']<=8)]

df_USASSeniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0   Employment    YearsCode  YearsCodePro  PreviousSalary  \
# count   4514.000000  4514.000000  4514.000000   4514.000000     4514.000000
# mean   36723.732831     0.966105    10.669473      5.802393   119975.310589
# std    21342.998462     0.180978     4.643193      1.380416    42170.274300
# min       48.000000     0.000000     1.000000      4.000000       91.000000
# 25%    18291.250000     1.000000     8.000000      5.000000    90000.000000
# 50%    37665.500000     1.000000    10.000000      6.000000   118000.000000
# 75%    54813.500000     1.000000    12.000000      7.000000   150000.000000
# max    73456.000000     1.000000    50.000000      8.000000   223000.000000
#
#        ComputerSkills     Employed
# count     4514.000000  4514.000000
# mean        13.699601     0.543199
# std          6.706976     0.498186
# min          0.000000     0.000000
# 25%          9.000000     0.000000
# 50%         13.000000     1.000000
# ...

# %%
#SEMISENIOR USA
sns.histplot(data=df_USASSeniorXYearsCodePro, x='PreviousSalary')
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %%
df_USAJuniorXYearsCodePro = df_USA[(df_USA['YearsCodePro']<=3)]
df_USAJuniorXYearsCodePro.describe()
# Out:
#          Unnamed: 0   Employment    YearsCode  YearsCodePro  PreviousSalary  \
# count   3160.000000  3160.000000  3160.000000   3160.000000     3160.000000
# mean   36289.485127     0.947468     6.704747      1.844304    93334.529747
# std    21161.367891     0.223132     3.726717      1.063272    39876.900093
# min       13.000000     0.000000     0.000000      0.000000      100.000000
# 25%    18352.750000     1.000000     4.000000      1.000000    67000.000000
# 50%    37104.500000     1.000000     6.000000      2.000000    87000.000000
# 75%    54125.250000     1.000000     8.000000      3.000000   115000.000000
# max    73460.000000     1.000000    43.000000      3.000000   220000.000000
#
#        ComputerSkills     Employed
# count     3160.000000  3160.000000
# mean        12.759494     0.511709
# std          6.594558     0.499942
# min          1.000000     0.000000
# 25%          8.000000     0.000000
# 50%         12.000000     1.000000
# ...

# %%
# Junior USA
sns.histplot(data=df_USAJuniorXYearsCodePro, x='PreviousSalary', kde=True)
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %%
sns.histplot(data=df_USAJuniorXYearsCodePro, x='PreviousSalary', hue='Gender', palette='rocket', bins=6, kde=True)
# Out:
# <Axes: xlabel='PreviousSalary', ylabel='Count'>

# %% [markdown]
# # Grafico de barras

# %%
sns.barplot(data=df_USA, x='Gender', y='PreviousSalary', hue='Age', palette='hls')
# Out:
# <Axes: xlabel='Gender', ylabel='PreviousSalary'>

# %%
sns.scatterplot(data=df_USA, x='PreviousSalary', y='YearsCodePro', palette='hls')
# Out:
# C:\Users\odstf\AppData\Local\Temp\ipykernel_2380\367153087.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_USA, x='PreviousSalary', y='YearsCodePro', palette='hls')
# <Axes: xlabel='PreviousSalary', ylabel='YearsCodePro'>

# %%
sns.scatterplot(data=df_USA, x='YearsCode', y='YearsCodePro', palette='hls')
# Out:
# C:\Users\odstf\AppData\Local\Temp\ipykernel_2380\3042318387.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_USA, x='YearsCode', y='YearsCodePro', palette='hls')
# <Axes: xlabel='YearsCode', ylabel='YearsCodePro'>

# %%
sns.regplot(data=df_USA, x='YearsCode', y='YearsCodePro')
# Out:
# <Axes: xlabel='YearsCode', ylabel='YearsCodePro'>

# %% [markdown]
# ## Grafico de regresion lineal (Años profesionales VS Salario)

# %%
sns.regplot(data=df_USA, x='YearsCodePro', y='PreviousSalary', line_kws={'color':'yellow'})
# Out:
# <Axes: xlabel='YearsCodePro', ylabel='PreviousSalary'>

# %% [markdown]
# # Conclusiones del Análisis Exploratorio
#
# ## Hallazgos Principales
#
# - La columna 'Have worked with' presenta **63 valores nulos** que requieren tratamiento antes del análisis posterior
# - Se identificó una columna sin nombre ('Unnamed') que corresponde al índice automático generado por pandas y puede ser eliminada del dataset para optimizar el análisis
#
# ## Recomendaciones
#
# - **Tratamiento de valores nulos:** Evaluar si los 63 registros faltantes en 'Have worked with' deben imputarse, eliminarse o tratarse como categoría separada
# - **Limpieza de columnas:** Remover la columna índice automática para reducir dimensionalidad innecesaria
