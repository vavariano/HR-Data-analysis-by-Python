# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#          candidate_id  Age Accessibility        EdLevel  Employment Gender  \
# work_id
# 0                   0  <35            No         Master           1    Man
# 1                   1  <35            No  Undergraduate           1    Man
# 2                   2  <35            No         Master           1    Man
# 3                   3  <35            No  Undergraduate           1    Man
# 4                   4  >35            No            PhD           0    Man
#
#         MentalHealth MainBranch  YearsCode  YearsCodePro    Country  \
# work_id
# 0                 No        Dev          7             4     Sweden
# 1                 No        Dev         12             5      Spain
# 2                 No        Dev         15             6    Germany
# 3                 No        Dev          9             6     Canada
# 4                 No     NotDev         40            30  Singapore
#
#          PreviousSalary                                     HaveWorkedWith  \
# ...

# %%
df.index.name = 'work_id'

# %%
df_work = df[['YearsCode','YearsCodePro','ComputerSkills','MainBranch','candidate_id']]
df_work.head(5)
# Out:
#          YearsCode  YearsCodePro  ComputerSkills MainBranch  candidate_id
# work_id
# 0                7             4               4        Dev             0
# 1               12             5              12        Dev             1
# 2               15             6               7        Dev             2
# 3                9             6              13        Dev             3
# 4               40            30               2     NotDev             4

# %%
df_work.to_csv('../data/split_tabs/work.csv')
df_work.head()
# Out:
#          YearsCode  YearsCodePro  ComputerSkills MainBranch  candidate_id
# work_id
# 0                7             4               4        Dev             0
# 1               12             5              12        Dev             1
# 2               15             6               7        Dev             2
# 3                9             6              13        Dev             3
# 4               40            30               2     NotDev             4
