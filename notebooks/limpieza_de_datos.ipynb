# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 0           0  <35            No         Master           1    Man
# 1           1  <35            No  Undergraduate           1    Man
# 2           2  <35            No         Master           1    Man
# 3           3  <35            No  Undergraduate           1    Man
# 4           4  >35            No            PhD           0    Man
#
#   MentalHealth MainBranch  YearsCode  YearsCodePro    Country  PreviousSalary  \
# 0           No        Dev          7             4     Sweden         51552.0
# 1           No        Dev         12             5      Spain         46482.0
# 2           No        Dev         15             6    Germany         77290.0
# 3           No        Dev          9             6     Canada         46135.0
# 4           No     NotDev         40            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  Employed
# ...

# %% [markdown]
# ## Eliminacion de datos nulos / Columna 'Have worked with'

# %%
df.isnull().sum()

#Se refiere a strings con valores rotos
# Out:
# Unnamed: 0         0
# Age                0
# Accessibility      0
# EdLevel            0
# Employment         0
# Gender             0
# MentalHealth       0
# MainBranch         0
# YearsCode          0
# YearsCodePro       0
# Country            0
# PreviousSalary     0
# HaveWorkedWith    63
# ComputerSkills     0
# Employed           0
# dtype: int64

# %%
df.isna().sum()

#Se refiere a numeros rotos
# Out:
# Unnamed: 0         0
# Age                0
# Accessibility      0
# EdLevel            0
# Employment         0
# Gender             0
# MentalHealth       0
# MainBranch         0
# YearsCode          0
# YearsCodePro       0
# Country            0
# PreviousSalary     0
# HaveWorkedWith    63
# ComputerSkills     0
# Employed           0
# dtype: int64

# %%
df[df['HaveWorkedWith'].isna()==True]
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 1161         1161  >35            No  Undergraduate           1    Man
# 2443         2443  >35            No          Other           1    Man
# 2533         2533  >35            No            PhD           1    Man
# 2657         2657  <35            No         Master           0  Woman
# 5797         5797  <35            No  Undergraduate           1    Man
# ...           ...  ...           ...            ...         ...    ...
# 69865       69865  <35            No          Other           1    Man
# 71795       71795  <35            No  Undergraduate           1    Man
# 72153       72153  >35           Yes          Other           1    Man
# 72588       72588  <35            No          Other           1    Man
# 72593       72593  <35            No  Undergraduate           1  Woman
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 1161           Yes        Dev         36            32
# ...

# %%
df.dropna()
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment     Gender  \
# 0               0  <35            No         Master           1        Man
# 1               1  <35            No  Undergraduate           1        Man
# 2               2  <35            No         Master           1        Man
# 3               3  <35            No  Undergraduate           1        Man
# 4               4  >35            No            PhD           0        Man
# ...           ...  ...           ...            ...         ...        ...
# 73457       73457  <35            No  Undergraduate           1        Man
# 73458       73458  >35            No  Undergraduate           1        Man
# 73459       73459  <35            No  Undergraduate           1        Man
# 73460       73460  <35           Yes  Undergraduate           1        Man
# 73461       73461  <35            No         Master           1  NonBinary
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# ...

# %%
df[df['HaveWorkedWith'].isna()==True]
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 1161         1161  >35            No  Undergraduate           1    Man
# 2443         2443  >35            No          Other           1    Man
# 2533         2533  >35            No            PhD           1    Man
# 2657         2657  <35            No         Master           0  Woman
# 5797         5797  <35            No  Undergraduate           1    Man
# ...           ...  ...           ...            ...         ...    ...
# 69865       69865  <35            No          Other           1    Man
# 71795       71795  <35            No  Undergraduate           1    Man
# 72153       72153  >35           Yes          Other           1    Man
# 72588       72588  <35            No          Other           1    Man
# 72593       72593  <35            No  Undergraduate           1  Woman
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 1161           Yes        Dev         36            32
# ...

# %%
df=df.dropna()

# %%
df[df['HaveWorkedWith'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Accessibility, EdLevel, Employment, Gender, MentalHealth, MainBranch, YearsCode, YearsCodePro, Country, PreviousSalary, HaveWorkedWith, ComputerSkills, Employed]
# Index: []

# %% [markdown]
# # Eliminacion de Columna 'Unnamed'

# %%
df['Unnamed: 0']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 73457    73457
# 73458    73458
# 73459    73459
# 73460    73460
# 73461    73461
# Name: Unnamed: 0, Length: 73399, dtype: int64

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#    Age Accessibility        EdLevel  Employment Gender MentalHealth  \
# 0  <35            No         Master           1    Man           No
# 1  <35            No  Undergraduate           1    Man           No
# 2  <35            No         Master           1    Man           No
# 3  <35            No  Undergraduate           1    Man           No
# 4  >35            No            PhD           0    Man           No
#
#   MainBranch  YearsCode  YearsCodePro    Country  PreviousSalary  \
# 0        Dev          7             4     Sweden         51552.0
# 1        Dev         12             5      Spain         46482.0
# 2        Dev         15             6    Germany         77290.0
# 3        Dev          9             6     Canada         46135.0
# 4     NotDev         40            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  Employed
# 0                          C++;Python;Git;PostgreSQL               4         0
# ...

# %%
df.to_csv('../data/processed/stackoverflow_full.csv',index=False)
