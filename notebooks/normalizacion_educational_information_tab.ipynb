# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/stackoverflow_full.csv')

# %%
df.head(5)
# Out:
#                 candidate_id  Age Accessibility        EdLevel  Employment  \
# recruitment_id
# 0                          0  <35            No         Master           1
# 1                          1  <35            No  Undergraduate           1
# 2                          2  <35            No         Master           1
# 3                          3  <35            No  Undergraduate           1
# 4                          4  >35            No            PhD           0
#
#                Gender MentalHealth MainBranch  YearsCode  YearsCodePro  \
# recruitment_id
# 0                 Man           No        Dev          7             4
# 1                 Man           No        Dev         12             5
# 2                 Man           No        Dev         15             6
# 3                 Man           No        Dev          9             6
# 4                 Man           No     NotDev         40            30
#
#                   Country  PreviousSalary  \
# ...

# %%
df.index.name = 'recruitment_id'

# %%
df_recruitment_information = df[['PreviousSalary','Employed', 'MentalHealth','candidate_id']]
df_recruitment_information.head(5)
# Out:
#                 PreviousSalary  Employed MentalHealth  candidate_id
# recruitment_id
# 0                      51552.0         0           No             0
# 1                      46482.0         1           No             1
# 2                      77290.0         0           No             2
# 3                      46135.0         0           No             3
# 4                     160932.0         0           No             4

# %%
df_recruitment_information.to_csv('../data/split_tabs/recruitment_information.csv')
df_recruitment_information.head()
# Out:
#                 PreviousSalary  Employed MentalHealth  candidate_id
# recruitment_id
# 0                      51552.0         0           No             0
# 1                      46482.0         1           No             1
# 2                      77290.0         0           No             2
# 3                      46135.0         0           No             3
# 4                     160932.0         0           No             4
